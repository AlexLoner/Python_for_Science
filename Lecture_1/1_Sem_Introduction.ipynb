# %% [markdown]
# ### Задание 1
# ---
# Определите, является ли строка палиндромом.
#
# Палиндром - слово или фраза, которые одинаково читаются слева направо и справа налево.
#
# ***Формат ввода***
#
# На вход подается строка произвольной длины.
#
# Hint: для ввода с клавиатуры воспользуйтесь функцией `input()` (возвращаемый тип будет `str`)
#
#
# ***Формат вывода***
#
# True или False
#
#
# | Input | Output |
# | --- | --- |
# | 'adss' | False |
# | 'level' | True |
# | 'A' | True |

# %% [markdown]
# ### Задание 2
# ---
# Необходимо найти в бинарном списке (состоит из 1 или 0) самую длинную последовательность единиц и вывести её длину.
#
# ***Формат ввода***
#
# Первая строка содержит одно число *n* - число элементов в списке. Каждая из следующих строк содержит ровно одно число &ndash; очередной элемент массива.
#
# Hint: для ввода с клавиатуры воспользуйтесь функцией `input()` (возвращаемый тип будет `str`)
#
#
# ***Формат вывода***
#
# Выходной файл должен содержать единственое число &ndash; длину самой длинной последовательности единиц во входном массиве.
#
# | Input | Output |
# | --- | --- |
# | 5 | 1 |
# | 1 | |
# | 0 | |
# | 1 | |
# | 0 | |
# | 1 | |

# %% [markdown]
# ### Задание 3
# ---
# Необходимо сосчитать число выбранных элементов в последовательности. Гарантируется, что "избранные" элементы уникалны.
#
# ***Формат ввода***
#
# Сначала строкой задаются "избранные" элементы. Второй строкой  - полный набор символов.
#
# ***Формат вывода***
#
# Одно число  &ndash количество выбранных элементов во второй строке.
#
# | Input | Output |
# | --- | --- |
# | "ab" | 5 |
# | 'abbacdaler' |  |

# %% [markdown]
# ### Задание 4
# ---
# Найти значение $ln(1.1)$ с помощью разложения Тейлора. Учесть слагаемые величной не менее $10^{-6}$.
#
# ![ln Taylor](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c6b185d43ac6d4e5c89b0a8c041850d8fb2b032)

# %% [markdown]
# ### Задание 5
# ---
# С клавиатуры вводится последовательность целых чисел, разделенных пробелом.
# Напишите программу, которая возводит в третью степень все числа кратные 6.
# Выведите последовательность этих чисел через пробел
#
# | Input | Output |
# | ----- | ------ |
# | 1 12 6 13  |1728 216 |

# %% [markdown]
# ### Задание 6
# ---
# Имеется массив `mass` экспериментальных данных зависимости интенсивности излучения от времени , где значение элемента является величиной интенсивности в условных единицах, а его индекс - время в секундах. Найти время, при которой интенсивность максимальна на первых 10 секундах.

# %%
import numpy as np
mass = list(np.random.random_sample(100))

# %% [markdown]
# ### Задание 7
# ---
# Имеется словарь `melt`, где ключом является вещество (состоящее максимум из двух элеметов), а значением его температура плавления.
#
# Вывести температуры плавления всех оксидов
#
# Примечание: оксид - бинарное соединение химического элемента с кислородом (CuO, SO3,CuO4 и т.д.)

# %%
melt = {'SiO2' : 1600  , 'MoS2': 1185, 'WS2':1234, 'FeO2':1377, 'Pb': 327,  'H':-259, 'Na2O': 1132, 'C3O2': -107, 'Hg': -38.83, 'Mg':650, 'Gd':1586, 'H2O': 0}
